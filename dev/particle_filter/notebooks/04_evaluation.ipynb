# %% [markdown]
# # 04 Evaluation
#
# This notebook is a tutorial scaffold for the beta MorphSeq predictor.

# %% [markdown]
# ## Purpose
#
# Summarize one-step and rollout accuracy, compare baselines, and inspect failure cases.

# %%
# from morphseq.dev.dynamo.eval.evaluate import run_evaluation_suite
# from morphseq.dev.dynamo.viz.evaluation import (
#     plot_error_vs_horizon,
#     plot_error_vs_support,
#     plot_failure_gallery,
# )

# %% [markdown]
# ## Run baseline comparisons
#
# Compare persistence, linear extrapolation, position-only local matching, full history matching, and fast summary matching.

# %%
# Example scaffold:
# results = run_evaluation_suite(...)

# %% [markdown]
# ## Plot summary metrics
#
# Visualize error vs horizon and inspect where support limitations drive failures.

# %%
# Example scaffold:
# fig = plot_error_vs_horizon(results)
# fig = plot_error_vs_support(results)

# %% [markdown]
# ## Failure gallery
#
# Inspect concrete examples where the model succeeds and fails.

# %%
# Example scaffold:
# fig = plot_failure_gallery(results, n_examples=12)
