# %% [markdown]
# # 00 Build Figure Data Cache
#
# Centralizes source data for the 20260528 figure notebooks. Missing analyses are recorded in `source_manifest.csv` and do not stop the cache build.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path.cwd()))
from figure_utils import CACHE_DIR, FIG_DIR, build_cache

manifest = build_cache()
manifest
# Out:
# /Users/nick/Projects/repositories/morphseq/results/nlammers/20260528/figure_utils.py:253: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   morph_df = pd.read_csv(train_fig[-1] / "embryo_stats_df.csv", index_col=0)
#                          analysis_name  \
# 0                    morph_hotfish_pca
# 1              morph_hotfish_pca_hooke
# 2         morph_reference_trajectories
# 3               morph_reference_spline
# 4                 seq_reference_spline
# 5               seq_hotfish_latent_pca
# 6            joint_141_morph_seq_stage
# 7                  joint_141_morph_seq
# 8        morph_distance_from_wt_spline
# 9                    seq_hooke_latents
# 10  latent_cell_type_count_correlation
# 11        latent_morph_variable_source
# 12   latent_morph_variable_correlation
# 13        pairwise_staging_correlation
# 14  curved_vs_normal_cell_type_volcano
#
#                             source_notebook_or_script  \
# ...

# %%
missing = manifest.loc[manifest['status'] == 'missing']
print(f'Cache directory: {CACHE_DIR}')
print(f'Figure directory: {FIG_DIR}')
print(f'Missing items: {len(missing)}')
missing
# Out:
# Cache directory: /Users/nick/Projects/data/morphseq/results/20260528
# Figure directory: /Users/nick/Projects/data/morphseq/results/20260528/figures
# Missing items: 0
# Empty DataFrame
# Columns: [analysis_name, source_notebook_or_script, source_data_path, output_cache_file, status, notes]
# Index: []
