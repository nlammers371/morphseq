# %%
import json


json_path = "/net/trapnell/vol1/home/mdcolon/proj/morphseq/segmentation_sandbox/data/annotation_and_masks/sam2_annotations/grounded_sam_annotations_finetuned.json"


gsam_annotations = json.load(open(json_path, "r"))

json_path = "/net/trapnell/vol1/home/mdcolon/proj/morphseq/segmentation_sandbox/data/annotation_and_masks/gdino_annotations/gdino_annotations_finetuned.json"

gdino_annotations = json.load(open(json_path, "r"))

# %%
gsam_annotations.keys()
gsam_annotations["experiment_ids"]
# Out:
# ['20240813',
#  '20250612',
#  '20250215',
#  '20250623',
#  '20250529',
#  '20230629',
#  '20250622',
#  '20241022',
#  '20240404',
#  '20230627',
#  '20240510',
#  '20250703',
#  '20240418',
#  '20230602',
#  '20240509',
#  '20250625',
#  '20240812',
#  '20240314',
#  '20240307',
#  '20231206',
#  '20250624',
#  '20240306',
#  '20230525',
#  '20240522',
#  '20230615',
#  '20231218',
#  '20240724',
#  '20240411',
#  '20230613',
#  '20230622',
#  '20250126',
#  '20250305',
#  '20230531',
#  '20240718',
#  '20240530',
#  '20230620',
#  '20231110',
#  '20231208',
#  '20230830',
#  '20231207',
#  '20241023',
#  '20240626',
#  '20240507',
#  '20240725']

# %%
gdino_annotations.keys()
# gdino_annotations["experiment_ids"]
# Out:
# dict_keys(['file_info', 'images', 'high_quality_annotations'])
