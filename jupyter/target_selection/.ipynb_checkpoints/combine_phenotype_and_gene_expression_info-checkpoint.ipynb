# %% [markdown]
# This notebook adds gene expression information to the previously built gene-phenotype table

# %%
import numpy as np
import pandas as pd
import umap.umap_ as umap
import plotly.express as px
import os

# %%
# set path to raw data
raw_data_root = "/Users/nick/Cole Trapnell's Lab Dropbox/Nick Lammers/Nick/morphseq/zfin/raw_data/"
access_date = "20240326"

gene_expression_df = pd.read_csv(os.path.join(raw_data_root, access_date, "wildtype-expression_fish_2024.04.08.txt"), 
                                sep='\t', header=1)
stage_df = pd.read_csv(os.path.join(raw_data_root, access_date, "stage_ontology.txt"), sep='\t', header=1)

# load built tables
built_data_dir = "/Users/nick/Cole Trapnell's Lab Dropbox/Nick Lammers/Nick/morphseq/zfin/built_data/20240326/"
if not os.path.isdir(built_data_dir):
    os.makedirs(built_data_dir)
    
pheno_df = pd.read_csv(os.path.join(built_data_dir, "condensed_gene_phenotypes.csv"))
KO_df = pd.read_csv(os.path.join(built_data_dir, "zfin_gene_KO_candidates.csv"))

# %% [markdown]
# ## Clean up the gene expression info

# %%
# clean up names
gene_df_clean = gene_expression_df.loc[:, ["Gene ID", "Gene Symbol", "Super Structure ID", "Super Structure Name",
                                          "Assay", "Start Stage", "End Stage"]].rename(columns={
                                "Gene Symbol" : "gene",
                                "Gene ID": "gene_ID",
                                "Super Structure ID": "structure_ID",
                                "Super Structure Name": "structure", "Assay": "assay"}).drop_duplicates()

# add hpf staging info
gene_df_clean = gene_df_clean.merge(stage_df.loc[:, ["Stage Name", "Begin Hours"]], how="left", 
                                    left_on="Start Stage", right_on="Stage Name").drop(columns="Stage Name")

gene_df_clean = gene_df_clean.rename(columns={"Begin Hours":"start_hpf"})

gene_df_clean = gene_df_clean.merge(stage_df.loc[:, ["Stage Name", "End Hours"]], how="left", 
                                    left_on="End Stage", right_on="Stage Name").drop(columns="Stage Name")

gene_df_clean = gene_df_clean.rename(columns={"End Hours":"end_hpf"}).drop(columns=["Start Stage", "End Stage"])

# filter for expression during relevant time period
print(gene_df_clean.shape)
gene_df_clean = gene_df_clean.loc[gene_df_clean["start_hpf"]<=72, :]
print(gene_df_clean.shape)

# remove entries with non-specific region tags
gene_df_clean = gene_df_clean.loc[gene_df_clean["structure"] != 'whole organism', :]
gene_df_clean = gene_df_clean.loc[gene_df_clean["structure"] != 'unspecified', :]
w_flags = np.asarray([1 if "WITHDRAWN" in gene else 0 for gene in list(gene_df_clean["gene"])])
print(gene_df_clean.shape)
gene_df_clean = gene_df_clean.loc[w_flags != 1, :]

print(gene_df_clean.shape)
# aggregate by gene-structure combination


gene_df_clean = gene_df_clean.sort_values(by=["gene", "structure"], axis=0, ascending=True)

# save
gene_df_clean.to_csv(os.path.join(built_data_dir, "gene_expression_cleaned.csv"), index=False)
gene_df_clean.head()
# Out:
# (202230, 7)
# (152910, 7)
# (120613, 7)
# (120602, 7)
#                   gene_ID  gene structure_ID             structure  \
# 197192  ZDB-GENE-060824-3  a1cf  ZFA:0000123                 liver
# 77448   ZDB-GENE-090212-1  a2ml  ZFA:0000123                 liver
# 36272   ZDB-GENE-090212-1  a2ml  ZFA:0000084                  yolk
# 39672   ZDB-GENE-090212-1  a2ml  ZFA:0000088  yolk syncytial layer
# 131005  ZDB-GENE-090212-1  a2ml  ZFA:0000088  yolk syncytial layer
#
#                              assay  start_hpf  end_hpf
# 197192  mRNA in situ hybridization       72.0    144.0
# 77448   mRNA in situ hybridization       72.0     96.0
# 36272   mRNA in situ hybridization       72.0     96.0
# 39672   mRNA in situ hybridization        6.0      8.0
# 131005  mRNA in situ hybridization        8.0      9.0

# %% [markdown]
# ## Join on gene expression info
# Simplest question to answer is just whether or not a given gene has documented specific expression

# %%
gene_df_temp = gene_df_clean.copy()
gene_df_temp["specific_expression_flag"] = 1
spec_df = gene_df_temp.loc[:, ["gene", "specific_expression_flag"]].drop_duplicates()

KO_out = KO_df.copy()
KO_out = KO_out.merge(spec_df, how="left", on="gene")
KO_out.loc[np.isnan(KO_out["specific_expression_flag"]), "specific_expression_flag"] = 0

print(np.mean(KO_out["specific_expression_flag"]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/network-env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/miniforge3/envs/network-env/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/envs/network-env/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'specific_expression_flag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 7
#       5 KO_out = KO_df.copy()
#       6 KO_out = KO_out.merge(spec_df, how="left", on="gene")
# ----> 7 KO_out.loc[np.isnan(KO_out["specific_expression_flag"]), "specific_expression_flag"] = 0
#       9 print(np.mean(KO_out["specific_expression_flag"]))
#
# File ~/miniforge3/envs/network-env/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/miniforge3/envs/network-env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'specific_expression_flag'

# %%
KO_df.head()
# Out:
#     gene              gene_ID  chromatin_flag  \
# 0  fosl2  ZDB-GENE-070209-164             0.0
# 1   vrtn  ZDB-GENE-060929-700             1.0
# 2  tbx16    ZDB-GENE-990615-5             1.0
# 3  hdac1   ZDB-GENE-020419-32             0.0
# 4   cdx4  ZDB-GENE-980526-330             1.0
#
#                                            gene_desc  TF_flag  \
# 0  Predicted to enable DNA-binding transcription ...      1.0
# 1  Enables DNA-binding transcription repressor ac...      1.0
# 2  Enables transcription cis-regulatory region bi...      1.0
# 3  Enables transcription corepressor activity. In...      1.0
# 4  Enables DNA binding activity and chromatin bin...      1.0
#
#    importance_score  n_zfin_reports           phenotype_1  \
# 0             973.0            10.0  anatomical structure
# 1             973.0             8.0  anatomical structure
# 2             259.0           103.0                  cell
# 3             163.0           131.0                somite
# 4             151.0            66.0     anatomical system
#
#                                        effect_1  start_hpf_1  ...  \
# 0                                        absent        30.00  ...
# 1            decreased amount, increased amount         5.25  ...
# 2                                  accumulation        24.00  ...
# 3  U-shaped, decreased amount, decreased amount        24.00  ...
# 4                                       quality         0.00  ...
#
#          phenotype_3                                  effect_3  start_hpf_3  \
# 0              heart  increased distribution, increased amount        48.00
# 1               head          decreased length, decreased size        11.66
# 2  surface structure                                   quality         0.00
# 3               head  decreased size, arrested, decreased size        48.00
# 4              trunk        decreased length, decreased length        24.00
#
#            phenotype_4                                           effect_4  \
# 0    cardiac ventricle  decreased size, increased rate, decreased amou...
# 1     optic primordium                             decreased distribution
# 2                 head                 increased height, decreased length
# 3  pharyngeal arch 3-7                          increased process quality
# 4             mesoderm            increased distribution, spatial pattern
#
#    start_hpf_4           phenotype_5  \
# 0         42.0                   NaN
# 1         10.0  forebrain neural rod
# 2         48.0           vasculature
# 3         48.0                 trunk
# 4         19.0         neuroectoderm
#
#                                             effect_5  start_hpf_5  \
# 0                                                NaN          NaN
# 1                             decreased distribution        11.66
# 2                                    spatial pattern        24.00
# 3                     curved, curved ventral, curved        24.00
# 4  spatial pattern, spatial pattern, decreased di...        11.66
#
#   specific_expression_flag
# 0                      1.0
# 1                      1.0
# 2                      1.0
# 3                      1.0
# 4                      1.0
#
# [5 rows x 23 columns]

# %%
KO_df = KO_df.loc[:, list(KO_df.columns[:5]) + ["specific_expression_flag"] + list(KO_df.columns[5:-1])]
KO_df = KO_df.sort_values(by=["TF_flag", "specific_expression_flag", "importance_score"], axis=0, ascending=False)

KO_df.to_csv(os.path.join(built_data_dir, "zfin_gene_KO_candidates_v2.csv"))
KO_df.head()
# Out:
#     gene              gene_ID  chromatin_flag  \
# 0  fosl2  ZDB-GENE-070209-164             0.0
# 1   vrtn  ZDB-GENE-060929-700             1.0
# 2  tbx16    ZDB-GENE-990615-5             1.0
# 3  hdac1   ZDB-GENE-020419-32             0.0
# 4   cdx4  ZDB-GENE-980526-330             1.0
#
#                                            gene_desc  TF_flag  \
# 0  Predicted to enable DNA-binding transcription ...      1.0
# 1  Enables DNA-binding transcription repressor ac...      1.0
# 2  Enables transcription cis-regulatory region bi...      1.0
# 3  Enables transcription corepressor activity. In...      1.0
# 4  Enables DNA binding activity and chromatin bin...      1.0
#
#    specific_expression_flag  importance_score  n_zfin_reports  \
# 0                       1.0             973.0            10.0
# 1                       1.0             973.0             8.0
# 2                       1.0             259.0           103.0
# 3                       1.0             163.0           131.0
# 4                       1.0             151.0            66.0
#
#             phenotype_1                                      effect_1  ...  \
# 0  anatomical structure                                        absent  ...
# 1  anatomical structure            decreased amount, increased amount  ...
# 2                  cell                                  accumulation  ...
# 3                somite  U-shaped, decreased amount, decreased amount  ...
# 4     anatomical system                                       quality  ...
#
#    start_hpf_2        phenotype_3                                  effect_3  \
# 0         48.0              heart  increased distribution, increased amount
# 1         36.0               head          decreased length, decreased size
# 2          0.0  surface structure                                   quality
# 3          0.0               head  decreased size, arrested, decreased size
# 4         16.0              trunk        decreased length, decreased length
#
#    start_hpf_3          phenotype_4  \
# 0        48.00    cardiac ventricle
# 1        11.66     optic primordium
# 2         0.00                 head
# 3        48.00  pharyngeal arch 3-7
# 4        24.00             mesoderm
#
#                                             effect_4  start_hpf_4  \
# 0  decreased size, increased rate, decreased amou...         42.0
# 1                             decreased distribution         10.0
# 2                 increased height, decreased length         48.0
# 3                          increased process quality         48.0
# 4            increased distribution, spatial pattern         19.0
#
#             phenotype_5                                           effect_5  \
# 0                   NaN                                                NaN
# 1  forebrain neural rod                             decreased distribution
# 2           vasculature                                    spatial pattern
# 3                 trunk                     curved, curved ventral, curved
# 4         neuroectoderm  spatial pattern, spatial pattern, decreased di...
#
#    start_hpf_5
# 0          NaN
# 1        11.66
# 2        24.00
# 3        24.00
# 4        11.66
#
# [5 rows x 23 columns]
