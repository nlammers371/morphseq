# %% [markdown]
# **The purpose of this notebook is to recapitulate in python the phenotype clustering script that Cole wrote in R.**
#
# **The key steps in this process are:**
# 1) Load and filter the raw phenotype data
# 2) Convert string phenotypes to wideform binary array
# 3) Perform UMAP compression and cluster

# %%
import numpy as np
import pandas as pd
import umap.umap_ as umap
import plotly.express as px
import os

# %% [markdown]
# ### Load phenotype data

# %%
# set path to raw data
raw_data_dir = "/Users/nick/Cole Trapnell's Lab Dropbox/Nick Lammers/Nick/morphseq/zfin/20240326/"

# set output directory
built_data_dir =  "/Users/nick/Cole Trapnell's Lab Dropbox/Nick Lammers/Nick/morphseq/zfin/20240326/built_data_py/" 
if not os.path.isdir(built_data_dir):
    os.makedirs(built_data_dir)
    
# load phenotype data and stage DF
phenotype_df_cole = pd.read_csv(os.path.join(raw_data_dir, "clean_zfin_single-mut_with-ids_phenotype_df.csv"))
# stage_to_hpf_key = pd.read_csv(os.path.join(raw_data_dir, "stage_to_hpf_key.csv"))
# phenotype_df = phenotype_df_raw.merge(stage_to_hpf_key, how = "left", on="start_stage")

# %% [markdown]
# ### Load ontology info

# %%
anatomy_nodes_df = pd.read_csv(os.path.join(raw_data_dir, "anatomy_item.txt"), sep='\t', header=1)
anatomy_edges_df = pd.read_csv(os.path.join(raw_data_dir, "anatomy_relationship.txt"), sep='\t', header=1)
anatomy_synonyms_df = pd.read_csv(os.path.join(raw_data_dir, "anatomy_synonyms.txt"), sep='\t', header=1)
zfin_pheno_df = pd.read_csv(os.path.join(raw_data_dir, "phenoGeneCleanData_fish.txt"), sep='\t', header=1)
stage_df = pd.read_csv(os.path.join(raw_data_dir, "stage_ontology.txt"), sep='\t', header=1)
# print(anatomy_edges_df.head())
# print(anatomy_nodes_df.head())
# Out:
# (152927, 10)
# (95889, 10)

# %% [markdown]
# ## Build cleaned zfin dataset

# %%
zfin_pheno_df = zfin_pheno_df.rename(columns={
            "Affected Structure or Process 1 superterm ID": "structure_1_ID",
            "Affected Structure or Process 1 superterm Name": "structure_1",
            "Affected Structure or Process 2 superterm ID": "structure_2_ID",
            "Affected Structure or Process 2 superterm name": "structure_2",
            "Gene Symbol" : "gene",
            "Gene ID": "gene_ID",
            "Phenotype Keyword ID": "pheno_ID"
}).loc[:, ["gene", "gene_ID", "structure_1", "structure_1_ID", "structure_2", "structure_2_ID", "pheno_ID",
           "Start Stage ID", "End Stage ID", "Figure ID"]]

zfin_pheno_df = zfin_pheno_df.merge(phenotype_df_cole.loc[:, "gene"].drop_duplicates(), how="inner", on="gene")
zfin_pheno_df = zfin_pheno_df.merge(stage_df.loc[:, ["Stage ID", "Begin Hours"]], how="left", 
                                    left_on="Start Stage ID", right_on="Stage ID")

zfin_pheno_df = zfin_pheno_df.rename(columns={"Begin Hours":"start_hpf"})

zfin_pheno_df = zfin_pheno_df.merge(stage_df.loc[:, ["Stage ID", "End Hours"]], how="left", 
                                    left_on="End Stage ID", right_on="Stage ID")

zfin_pheno_df = zfin_pheno_df.rename(columns={"End Hours":"end_hpf"})

# %% [markdown]
# ### Make phenotype DF longform

# %%
# zfin_pheno_long = pd.wide_to_long(zfin_pheno_df, stubnames=["structure"])
zfin_pheno_temp = zfin_pheno_df.copy()
# zfin_pheno_long["id"] = zfin_pheno_long.index
# id_key1 = zfin_pheno_long.loc[:, ["structure_1", "structure_1_ID"]].rename(columns={"structure_1":"structure", 
#                                                                                     "structure_1":"ID"})
# id_key2 = zfin_pheno_long.loc[:, ["structure_2", "structure_2_ID"]].rename(columns={"structure_2":"structure", 
#                                                                                     "structure_2":"ID"})
                                                                           
# id_key = pd.concat([id_key1, id_key2], axis=0, ignore_index=True).drop_duplicates()

zfin_pheno1 = zfin_pheno_temp.drop(labels=["structure_2", "structure_2_ID", "Stage ID_x", "Stage ID_y"], 
                                   axis=1).rename(columns={"structure_1":"structure", 
                                                                                    "structure_1_ID":"ID"})

zfin_pheno2 = zfin_pheno_temp.drop(labels=["structure_1", "structure_1_ID", "Stage ID_x", "Stage ID_y"], 
                                   axis=1).rename(columns={"structure_2":"structure", 
                                                                                    "structure_2_ID":"ID"})

zfin_pheno_long = pd.concat([zfin_pheno1, zfin_pheno2], axis=0, ignore_index=True).dropna(
    subset=["structure", "ID"]).drop_duplicates()


zfin_pheno_long.head()
zfin_pheno_long.to_csv(os.path.join(built_data_dir, "zfin_phenotypes_clean.csv"), index=False)

# %% [markdown]
# ## Clean up anatomy data and build an ontology graph

# %%
# First, construct full graph
edge_vec = anatomy_edges_df["Relationship Type ID"].to_list()
keep_edge_types = ["is_a", "part of"]
keep_flags = np.asarray([e in keep_edge_types for e in edge_vec])

# filter for only desired edge types
edge_df = anatomy_edges_df.loc[keep_flags, ["Parent Item ID", "Child Item ID", "Relationship Type ID"]]
edge_df.reset_index(inplace=True, drop=True)
node_df = anatomy_nodes_df.loc[:, ["Anatomy ID", "Anatomy Name"]].drop_duplicates()
node_df.reset_index(inplace=True, drop=True)
node_df.loc[:, "node_id"] = node_df.index
# construct node dictionary
anatomy_nodes_id_vec = node_df["Anatomy ID"].to_numpy()
node_container = []
for i, a_term in enumerate(node_df["Anatomy Name"]):
    node_container.append(tuple([i, {"name": a_term, "id": anatomy_nodes_id_vec[i]}]))


# join node df to edges to get edge IDs
edge_df = edge_df.merge(node_df.loc[:, ["Anatomy ID", "node_id"]], 
                        how="left", left_on="Parent Item ID", right_on="Anatomy ID")
edge_df = edge_df.rename(columns={"node_id":"from_id"})

edge_df = edge_df.merge(node_df.loc[:, ["Anatomy ID", "node_id"]], 
                        how="left", left_on="Child Item ID", right_on="Anatomy ID")
edge_df = edge_df.rename(columns={"node_id":"to_id"})
                         
edge_df = edge_df.loc[:, ["Parent Item ID", "Child Item ID", "Relationship Type ID", "from_id", "to_id"]]
edge_df = edge_df.dropna(subset=["from_id", "to_id"])
edge_df.reset_index(inplace=True, drop=True)
edge_df.head()
# Out:
#   Parent Item ID Child Item ID Relationship Type ID  from_id  to_id
# 0    ZFA:0001129   ZFA:0001130                 is_a   2112.0   2107
# 1    ZFA:0001129   ZFA:0001131                 is_a   2112.0   2108
# 2    ZFA:0001129   ZFA:0001132                 is_a   2112.0   2111
# 3    ZFA:0001129   ZFA:0001133                 is_a   2112.0   2110
# 4    ZFA:0001129   ZFA:0001134                 is_a   2112.0   2109

# %%
import networkx as nx
a_graph = nx.Graph()
a_graph.add_nodes_from(node_container)

edge_container = []
for i in range(edge_df.shape[0]):
    edge_container.append(tuple([edge_df.loc[i, "from_id"], edge_df.loc[i, "to_id"]]))
    
a_graph.add_edges_from(edge_container)

# %%
# import matplotlib.pyplot as plt

# # pos = nx.nx_agraph.graphviz_layout(a_graph, prog="twopi", args="")
# # x_vec = [pos[i][0] for i in range(len(pos))]
# # y_vec = [pos[i][1] for i in range(len(pos))]

# pos = nx.nx_agraph.graphviz_layout(a_graph, prog="twopi", args="")
# plt.figure(figsize=(8, 8))
# nx.draw(a_graph, pos, node_size=20, alpha=0.5, node_color="blue", with_labels=False)
# plt.axis("equal")
# plt.show()

# %%
pos[1][0]
# Out:
# 2425.1

# %% [markdown]
# ### Calculate graph distance between all genes in the phenotypes dataset

# %%
import plotly.express as px
distance_mat = dict(nx.shortest_path_length(a_graph))
px.imshow(distance_mat)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 3
#       1 import plotly.express as px
#       2 distance_mat = dict(nx.shortest_path_length(a_graph))
# ----> 3 px.imshow(distance_mat)
#
# File ~/miniforge3/envs/pecfin-morph-env/lib/python3.10/site-packages/plotly/express/_imshow.py:375, in imshow(img, zmin, zmax, origin, labels, x, y, animation_frame, facet_col, facet_col_wrap, facet_col_spacing, facet_row_spacing, color_continuous_scale, color_continuous_midpoint, range_color, title, template, width, height, aspect, contrast_rescaling, binary_string, binary_backend, binary_compression_level, binary_format, text_auto)
#     372 else:
#     373     # For uint8 data and infer we let zmin and zmax to be None if passed as None
#     374     if zmax is None and img.dtype != np.uint8:
# --> 375         zmax = _infer_zmax_from_type(img)
#     376     if zmin is None and zmax is not None:
#     377         zmin = 0
#
# File ~/miniforge3/envs/pecfin-morph-env/lib/python3.10/site-packages/plotly/express/_imshow.py:45, in _infer_zmax_from_type(img)
#      43     return _integer_ranges[dt][1]
#      44 else:
# ---> 45     im_max = img[np.isfinite(img)].max()
#      46     if im_max <= 1 * rtol:
#      47         return 1
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
distance_mat[20][10]
# Out:
# 7

# %%
anatomy_nodes_df["flag"] = 1
phenotype_df_test = phenotype_df.merge(anatomy_nodes_df, left_on='aff_struct_super_1', 
                                       right_on= "Anatomy Name", how='left')


print(np.mean(~np.isnan(phenotype_df_test["flag"])))
phenotype_df_test.head(50)
# Out:
# 0.3381054678312138
#        gene         allele         start_stage           end_stage  \
# 0   aldh1a2        i26/i26             Unknown             Unknown
# 1   aldh1a2        i26/i26             Unknown             Unknown
# 2     kif11        hi486Tg             Unknown             Unknown
# 3     kif11        hi486Tg             Unknown             Unknown
# 4     kif11        hi486Tg             Unknown             Unknown
# 5     kif11        hi486Tg             Unknown             Unknown
# 6     sdad1        hi297Tg             Unknown             Unknown
# 7     sdad1        hi297Tg             Unknown             Unknown
# 8     sdad1        hi297Tg             Unknown             Unknown
# 9     sdad1        hi297Tg             Unknown             Unknown
# 10    sox9a       hi1134Tg  Pharyngula:Prim-25  Pharyngula:Prim-25
# 11      pkp          p48qg               Adult               Adult
# 12      pkp          p48qg             Unknown             Unknown
# 13  sec61a1      hi2839bTg             Unknown             Unknown
# 14  sec61a1      hi2839bTg             Unknown             Unknown
# 15  sec61a1      hi2839bTg             Unknown             Unknown
# 16  sec61a1      hi2839bTg             Unknown             Unknown
# 17  sec61a1      hi2839bTg             Unknown             Unknown
# 18  sec61a1      hi2839bTg             Unknown             Unknown
# 19  sec61a1      hi2839bTg             Unknown             Unknown
# 20    pole2       hi1703Tg             Unknown             Unknown
# 21     rpl3       hi2437Tg             Unknown             Unknown
# 22    trnt1       hi1167Tg             Unknown             Unknown
# 23    trnt1       hi1167Tg             Unknown             Unknown
# 24     fgf3  t21142/t21142             Unknown             Unknown
# 25     fgf3  t21142/t21142             Unknown             Unknown
# 26     fgf3  t21142/t21142             Unknown             Unknown
# 27     fgf3  t21142/t21142             Unknown             Unknown
# 28      boj           s307             Unknown             Unknown
# 29   smc1al       hi2327Tg             Unknown             Unknown
# 30   mbtps1       hi1487Tg             Unknown             Unknown
# 31   mbtps1       hi1487Tg        Larval:Day 5        Larval:Day 5
# 32   mbtps1       hi1487Tg        Larval:Day 5        Larval:Day 5
# 33  rnf113a       hi3013Tg             Unknown             Unknown
# 34  rnf113a       hi3013Tg             Unknown             Unknown
# 35  rnf113a       hi3013Tg             Unknown             Unknown
# 36  rnf113a       hi3013Tg             Unknown             Unknown
# 37  rnf113a       hi3013Tg             Unknown             Unknown
# 38  rnf113a       hi3013Tg             Unknown             Unknown
# 39    thoc2       hi3237Tg        Larval:Day 5        Larval:Day 5
# 40    thoc2       hi3237Tg        Larval:Day 5        Larval:Day 5
# 41    thoc2       hi3237Tg             Unknown             Unknown
# 42    thoc2       hi3237Tg             Unknown             Unknown
# 43    thoc2       hi3237Tg             Unknown             Unknown
# 44    thoc2       hi3237Tg             Unknown             Unknown
# 45    thoc2       hi3237Tg             Unknown             Unknown
# 46     copa       hi3669Tg             Unknown             Unknown
# 47     copa       hi3669Tg             Unknown             Unknown
# 48     copa       hi3669Tg             Unknown             Unknown
# 49     copa       hi3669Tg             Unknown             Unknown
#
#            phen_type  phen_tag            aff_struct_super_1 aff_struct_sub_1  \
# 0            quality  abnormal  pharyngeal_arch_3-7_skeleton              NaN
# 1            quality  abnormal                  pectoral_fin              NaN
# 2           necrotic  abnormal                         brain              NaN
# 3     decreased size  abnormal                           eye              NaN
# 4            quality  abnormal                     inner_ear              NaN
# 5               bent  abnormal                whole_organism              NaN
# 6     decreased size  abnormal                           eye              NaN
# 7            quality  abnormal                           gut              NaN
# 8            quality  abnormal                         heart              NaN
# 9            quality  abnormal                         liver              NaN
# 10          aplastic  abnormal                  otic_vesicle              NaN
# 11           quality  abnormal                  pigment_cell              NaN
# 12           quality  abnormal                  pigment_cell              NaN
# 13           quality  abnormal  pharyngeal_arch_3-7_skeleton              NaN
# 14    decreased size  abnormal                           eye              NaN
# 15           quality  abnormal                           gut              NaN
# 16           quality  abnormal                         heart              NaN
# 17           quality  abnormal                         liver              NaN
# 18              bent  abnormal                whole_organism              NaN
# 19           quality  abnormal                       otolith              NaN
# 20          necrotic  abnormal                         brain              NaN
# 21           quality  abnormal                whole_organism              NaN
# 22    decreased size  abnormal                           eye              NaN
# 23           quality  abnormal                           gut              NaN
# 24           quality  abnormal                         brain              NaN
# 25           quality  abnormal  pharyngeal_arch_3-7_skeleton              NaN
# 26           quality  abnormal                    hypophysis              NaN
# 27           quality  abnormal                     inner_ear              NaN
# 28           quality  abnormal   retinal_ganglion_cell_layer              NaN
# 29          necrotic  abnormal                         brain              NaN
# 30           quality  abnormal  pharyngeal_arch_3-7_skeleton              NaN
# 31         disrupted  abnormal             brain_development              NaN
# 32          circular  abnormal                         liver              NaN
# 33    decreased size  abnormal                           eye              NaN
# 34           quality  abnormal                           gut              NaN
# 35           quality  abnormal                         heart              NaN
# 36           quality  abnormal                         liver              NaN
# 37             shape  abnormal                whole_organism              NaN
# 38           quality  abnormal             anatomical_system              NaN
# 39    increased size  abnormal                         liver              NaN
# 40    increased size  abnormal                    hepatocyte              NaN
# 41    decreased size  abnormal                           eye              NaN
# 42           quality  abnormal                           gut              NaN
# 43           quality  abnormal                         heart              NaN
# 44           quality  abnormal                         liver              NaN
# 45           quality  abnormal             anatomical_system              NaN
# 46           quality  abnormal                          yolk              NaN
# 47          undulate  abnormal                     notochord              NaN
# 48  decreased length  abnormal                whole_organism              NaN
# 49          necrotic  abnormal                whole_organism              NaN
#
#    aff_struct_super_2 aff_struct_sub_2  ... val             gene_id start_hpf  \
# 0                 NaN              NaN  ...   1  ENSDARG00000053493       NaN
# 1                 NaN              NaN  ...   1  ENSDARG00000053493       NaN
# 2                 NaN              NaN  ...   1  ENSDARG00000010948       NaN
# 3                 NaN              NaN  ...   1  ENSDARG00000010948       NaN
# 4                 NaN              NaN  ...   1  ENSDARG00000010948       NaN
# 5                 NaN              NaN  ...   1  ENSDARG00000010948       NaN
# 6                 NaN              NaN  ...   1  ENSDARG00000105117       NaN
# 7                 NaN              NaN  ...   1  ENSDARG00000105117       NaN
# 8                 NaN              NaN  ...   1  ENSDARG00000105117       NaN
# 9                 NaN              NaN  ...   1  ENSDARG00000105117       NaN
# 10                NaN              NaN  ...   1  ENSDARG00000003293      36.0
# 11                NaN              NaN  ...   1                None    2160.0
# 12                NaN              NaN  ...   1                None       NaN
# 13                NaN              NaN  ...   1  ENSDARG00000021669       NaN
# 14                NaN              NaN  ...   1  ENSDARG00000021669       NaN
# 15                NaN              NaN  ...   1  ENSDARG00000021669       NaN
# 16                NaN              NaN  ...   1  ENSDARG00000021669       NaN
# 17                NaN              NaN  ...   1  ENSDARG00000021669       NaN
# 18                NaN              NaN  ...   1  ENSDARG00000021669       NaN
# 19                NaN              NaN  ...   1  ENSDARG00000021669       NaN
# 20                NaN              NaN  ...   1  ENSDARG00000100028       NaN
# 21                NaN              NaN  ...   1  ENSDARG00000003599       NaN
# 22                NaN              NaN  ...   1  ENSDARG00000075297       NaN
# 23                NaN              NaN  ...   1  ENSDARG00000075297       NaN
# 24                NaN              NaN  ...   1  ENSDARG00000101540       NaN
# 25                NaN              NaN  ...   1  ENSDARG00000101540       NaN
# 26                NaN              NaN  ...   1  ENSDARG00000101540       NaN
# 27                NaN              NaN  ...   1  ENSDARG00000101540       NaN
# 28                NaN              NaN  ...   1                None       NaN
# 29                NaN              NaN  ...   1  ENSDARG00000058203       NaN
# 30                NaN              NaN  ...   1  ENSDARG00000014634       NaN
# 31                NaN              NaN  ...   1  ENSDARG00000014634     120.0
# 32                NaN              NaN  ...   1  ENSDARG00000014634     120.0
# 33                NaN              NaN  ...   1  ENSDARG00000037930       NaN
# 34                NaN              NaN  ...   1  ENSDARG00000037930       NaN
# 35                NaN              NaN  ...   1  ENSDARG00000037930       NaN
# 36                NaN              NaN  ...   1  ENSDARG00000037930       NaN
# 37                NaN              NaN  ...   1  ENSDARG00000037930       NaN
# 38                NaN              NaN  ...   1  ENSDARG00000037930       NaN
# 39                NaN              NaN  ...   1  ENSDARG00000037503     120.0
# 40                NaN              NaN  ...   1  ENSDARG00000037503     120.0
# 41                NaN              NaN  ...   1  ENSDARG00000037503       NaN
# 42                NaN              NaN  ...   1  ENSDARG00000037503       NaN
# 43                NaN              NaN  ...   1  ENSDARG00000037503       NaN
# 44                NaN              NaN  ...   1  ENSDARG00000037503       NaN
# 45                NaN              NaN  ...   1  ENSDARG00000037503       NaN
# 46                NaN              NaN  ...   1  ENSDARG00000004173       NaN
# 47                NaN              NaN  ...   1  ENSDARG00000004173       NaN
# 48                NaN              NaN  ...   1  ENSDARG00000004173       NaN
# 49                NaN              NaN  ...   1  ENSDARG00000004173       NaN
#
#     end_hpf   Anatomy ID Anatomy Name       Start Stage ID  \
# 0       NaN          NaN          NaN                  NaN
# 1       NaN          NaN          NaN                  NaN
# 2       NaN  ZFA:0000008        brain   ZDB-STAGE-020626-1
# 3       NaN  ZFA:0000107          eye  ZDB-STAGE-010723-10
# 4       NaN          NaN          NaN                  NaN
# 5       NaN          NaN          NaN                  NaN
# 6       NaN  ZFA:0000107          eye  ZDB-STAGE-010723-10
# 7       NaN  ZFA:0000112          gut   ZDB-STAGE-020626-1
# 8       NaN  ZFA:0000114        heart  ZDB-STAGE-010723-31
# 9       NaN  ZFA:0000123        liver  ZDB-STAGE-010723-32
# 10     42.0          NaN          NaN                  NaN
# 11   2160.0          NaN          NaN                  NaN
# 12      NaN          NaN          NaN                  NaN
# 13      NaN          NaN          NaN                  NaN
# 14      NaN  ZFA:0000107          eye  ZDB-STAGE-010723-10
# 15      NaN  ZFA:0000112          gut   ZDB-STAGE-020626-1
# 16      NaN  ZFA:0000114        heart  ZDB-STAGE-010723-31
# 17      NaN  ZFA:0000123        liver  ZDB-STAGE-010723-32
# 18      NaN          NaN          NaN                  NaN
# 19      NaN  ZFA:0001617      otolith  ZDB-STAGE-010723-16
# 20      NaN  ZFA:0000008        brain   ZDB-STAGE-020626-1
# 21      NaN          NaN          NaN                  NaN
# 22      NaN  ZFA:0000107          eye  ZDB-STAGE-010723-10
# 23      NaN  ZFA:0000112          gut   ZDB-STAGE-020626-1
# 24      NaN  ZFA:0000008        brain   ZDB-STAGE-020626-1
# 25      NaN          NaN          NaN                  NaN
# 26      NaN  ZFA:0000118   hypophysis  ZDB-STAGE-010723-16
# 27      NaN          NaN          NaN                  NaN
# 28      NaN          NaN          NaN                  NaN
# 29      NaN  ZFA:0000008        brain   ZDB-STAGE-020626-1
# 30      NaN          NaN          NaN                  NaN
# 31    144.0          NaN          NaN                  NaN
# 32    144.0  ZFA:0000123        liver  ZDB-STAGE-010723-32
# 33      NaN  ZFA:0000107          eye  ZDB-STAGE-010723-10
# 34      NaN  ZFA:0000112          gut   ZDB-STAGE-020626-1
# 35      NaN  ZFA:0000114        heart  ZDB-STAGE-010723-31
# 36      NaN  ZFA:0000123        liver  ZDB-STAGE-010723-32
# 37      NaN          NaN          NaN                  NaN
# 38      NaN          NaN          NaN                  NaN
# 39    144.0  ZFA:0000123        liver  ZDB-STAGE-010723-32
# 40    144.0  ZFA:0009111   hepatocyte   ZDB-STAGE-050211-1
# 41      NaN  ZFA:0000107          eye  ZDB-STAGE-010723-10
# 42      NaN  ZFA:0000112          gut   ZDB-STAGE-020626-1
# 43      NaN  ZFA:0000114        heart  ZDB-STAGE-010723-31
# 44      NaN  ZFA:0000123        liver  ZDB-STAGE-010723-32
# 45      NaN          NaN          NaN                  NaN
# 46      NaN  ZFA:0000084         yolk   ZDB-STAGE-010723-4
# 47      NaN  ZFA:0000135    notochord  ZDB-STAGE-010723-12
# 48      NaN          NaN          NaN                  NaN
# 49      NaN          NaN          NaN                  NaN
#
#            End Stage ID Unnamed: 4  flag
# 0                   NaN        NaN   NaN
# 1                   NaN        NaN   NaN
# 2   ZDB-STAGE-010723-39        NaN   1.0
# 3   ZDB-STAGE-010723-39        NaN   1.0
# 4                   NaN        NaN   NaN
# 5                   NaN        NaN   NaN
# 6   ZDB-STAGE-010723-39        NaN   1.0
# 7   ZDB-STAGE-010723-39        NaN   1.0
# 8   ZDB-STAGE-010723-39        NaN   1.0
# 9   ZDB-STAGE-010723-39        NaN   1.0
# 10                  NaN        NaN   NaN
# 11                  NaN        NaN   NaN
# 12                  NaN        NaN   NaN
# 13                  NaN        NaN   NaN
# 14  ZDB-STAGE-010723-39        NaN   1.0
# 15  ZDB-STAGE-010723-39        NaN   1.0
# 16  ZDB-STAGE-010723-39        NaN   1.0
# 17  ZDB-STAGE-010723-39        NaN   1.0
# 18                  NaN        NaN   NaN
# 19  ZDB-STAGE-010723-39        NaN   1.0
# 20  ZDB-STAGE-010723-39        NaN   1.0
# 21                  NaN        NaN   NaN
# 22  ZDB-STAGE-010723-39        NaN   1.0
# 23  ZDB-STAGE-010723-39        NaN   1.0
# 24  ZDB-STAGE-010723-39        NaN   1.0
# 25                  NaN        NaN   NaN
# 26  ZDB-STAGE-010723-39        NaN   1.0
# 27                  NaN        NaN   NaN
# 28                  NaN        NaN   NaN
# 29  ZDB-STAGE-010723-39        NaN   1.0
# 30                  NaN        NaN   NaN
# 31                  NaN        NaN   NaN
# 32  ZDB-STAGE-010723-39        NaN   1.0
# 33  ZDB-STAGE-010723-39        NaN   1.0
# 34  ZDB-STAGE-010723-39        NaN   1.0
# 35  ZDB-STAGE-010723-39        NaN   1.0
# 36  ZDB-STAGE-010723-39        NaN   1.0
# 37                  NaN        NaN   NaN
# 38                  NaN        NaN   NaN
# 39  ZDB-STAGE-010723-39        NaN   1.0
# 40  ZDB-STAGE-010723-39        NaN   1.0
# 41  ZDB-STAGE-010723-39        NaN   1.0
# 42  ZDB-STAGE-010723-39        NaN   1.0
# 43  ZDB-STAGE-010723-39        NaN   1.0
# 44  ZDB-STAGE-010723-39        NaN   1.0
# 45                  NaN        NaN   NaN
# 46  ZDB-STAGE-010723-36        NaN   1.0
# 47  ZDB-STAGE-010723-39        NaN   1.0
# 48                  NaN        NaN   NaN
# 49                  NaN        NaN   NaN
#
# [50 rows x 21 columns]

# %% [markdown]
# ### Perform some basic filtering steps

# %%
# remove phenotypes with late onset. Keep those with unknown onst time for now

phenotype_df.loc[np.isnan(phenotype_df["start_hpf"]), "start_hpf"] = -1
phenotype_df = phenotype_df.loc[phenotype_df["start_hpf"] < 72] # filter for phenotypes with onset prior to 3dpf

# %%
# remove rare phenotypes and uninformative phenotypes
min_freq = 4 # ad hoc threshold

phenotype_cat_df = phenotype_df.loc[:, ["aff_struct_super_1", "gene"]].groupby(["aff_struct_super_1"]).count()
phenotype_cat_df = phenotype_cat_df.rename(columns={"gene":"counts"})
phenotype_cat_df.reset_index(inplace=True)
# phenotype_cat_df = phenotype_cat_df.loc[phenotype_cat_df["counts"] >= min_freq, :]
# phenotype_cat_df = phenotype_cat_df.loc[phenotype_cat_df["aff_struct_super_1"] != "whole_organism"] # I don't find this useful

# %%
# use an inner join to filter
phenotype_df_long = phenotype_df.merge(phenotype_cat_df, how="inner", on="aff_struct_super_1")
phenotype_df_long = phenotype_df_long.loc[phenotype_df_long["phen_tag"] == "abnormal"] # this does nothing
phenotype_df_long["val"] = 1
phenotype_df_long.head()
# Out:
#       gene         allele start_stage end_stage phen_type  phen_tag  \
# 0  aldh1a2        i26/i26     Unknown   Unknown   quality  abnormal
# 1  sec61a1      hi2839bTg     Unknown   Unknown   quality  abnormal
# 2     fgf3  t21142/t21142     Unknown   Unknown   quality  abnormal
# 3   mbtps1       hi1487Tg     Unknown   Unknown   quality  abnormal
# 4    smad5    ta206/ta206     Unknown   Unknown   quality  abnormal
#
#              aff_struct_super_1 aff_struct_sub_1 aff_struct_super_2  \
# 0  pharyngeal_arch_3-7_skeleton              NaN                NaN
# 1  pharyngeal_arch_3-7_skeleton              NaN                NaN
# 2  pharyngeal_arch_3-7_skeleton              NaN                NaN
# 3  pharyngeal_arch_3-7_skeleton              NaN                NaN
# 4  pharyngeal_arch_3-7_skeleton              NaN                NaN
#
#   aff_struct_sub_2            pub_id  val             gene_id  start_hpf  \
# 0              NaN  ZDB-PUB-060503-2    1  ENSDARG00000053493       -1.0
# 1              NaN  ZDB-PUB-060503-2    1  ENSDARG00000021669       -1.0
# 2              NaN  ZDB-PUB-060503-2    1  ENSDARG00000101540       -1.0
# 3              NaN  ZDB-PUB-060503-2    1  ENSDARG00000014634       -1.0
# 4              NaN  ZDB-PUB-060503-2    1  ENSDARG00000037238       -1.0
#
#    end_hpf  counts
# 0      NaN     287
# 1      NaN     287
# 2      NaN     287
# 3      NaN     287
# 4      NaN     287

# %% [markdown]
# ## Generate a matrix that we can use for UMAP compression and clustering

# %%
pheno_df_wide = pd.pivot_table(phenotype_df_long.loc[:, ["gene", "start_hpf", "aff_struct_super_1", "val"]],
                         index=["gene"], values=["val"], columns=["aff_struct_super_1"],
                              fill_value=0)

pheno_df_wide.reset_index(inplace=True)
pheno_df_wide.columns = pheno_df_wide.columns.get_level_values(1)
pheno_df_wide = pheno_df_wide.rename(columns={"": "gene"})

# %% [markdown]
# ## Calculate UMAP projection

# %%
from sklearn.decomposition import TruncatedSVD, PCA

# pull out binary phenotype array
phen_mat = pheno_df_wide.iloc[:, 1:].to_numpy()

# first, we need to use LSA to obtain lower-dim input for UMAP
# n_lsa_comp = 3
# svd_model = TruncatedSVD(n_components=n_lsa_comp, 
#                          algorithm='randomized',
#                          n_iter=10, random_state=42)
# svd_model.fit(phen_mat.T)

transformer = PCA(n_components=5, random_state=0)
transformer.fit(phen_mat.T)
# Out:
# PCA(n_components=5, random_state=0)

# %%
transformer.components_.shape
# Out:
# (5, 3116)

# %%
from sklearn.preprocessing import StandardScaler

n_umap_comp = 2
# fit UMAP
svd_components = transformer.components_.T
reducer = umap.UMAP(n_components=n_umap_comp)
# scaled_svd = StandardScaler().fit_transform(svd_components)
embedding = reducer.fit_transform(svd_components)

# %%
fig = px.scatter(x=embedding[:, 0], y=embedding[:, 1])
fig.show()
# Out:
# <div>                            <div id="a5b4ae54-ec40-408c-82be-3f02da0017fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5b4ae54-ec40-408c-82be-3f02da0017fd")) {                    Plotly.newPlot(                        "a5b4ae54-ec40-408c-82be-3f02da0017fd",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[23.701885223388672,4.486791133880615,2.379608392715454,2.451984405517578,4.447588920593262,23.745397567749023,25.407493591308594,2.0393199920654297,2.85971999168396,23.03329849243164,5.309571266174316,3.5670783519744873,38.53327941894531,21.105758666992188,8.39549732208252,24.89550018310547,9.62969970703125,5.878080368041992,38.418426513671875,3.0864923000335693,5.552180767059326,23.65093231201172,24.621234893798828,14.850518226623535,14.868155479431152,38.58719253540039,19.55634307861328,5.381502151489258,23.954509735107422,12.152762413024902,2.062108278274536,6.70339822769165,21.278160095214844,12.036744117736816,8.754892349243164,23.210905075073242,2.721074104309082,9.688026428222656,7.768723487854004,2.8008124828338623,-13.928593635559082,1.7061939239501953,3.3173885345458984,38.454063415527344,2.3757638931274414,2.376206874847412,8.912337303161621,10.132343292236328,8.393119812011719,7.276591777801514,7.051938533782959,10.961713790893555,4.628844738006592,5.229856014251709,10.963055610656738,38.44365692138672,2.388545513153076,13.213340759277344,23.3882999420166,8.748390197753906,7.293485641479492,9.81894588470459,6.352524280548096,2.438861846923828,4.456794738769531,19.580516815185547,3.536604404449463,9.206355094909668,2.5101306438446045,9.808916091918945,7.230984210968018,8.761384963989258,2.4555323123931885,9.821584701538086,4.000320911407471,23.353342056274414,5.791116237640381,8.441804885864258,7.127405166625977,8.054964065551758,-13.902433395385742,-13.872153282165527,6.489819049835205,7.859259128570557,11.396180152893066,23.066017150878906,9.818188667297363,19.436185836791992,13.736706733703613,38.71479797363281,4.411514759063721,8.063434600830078,11.624029159545898,13.775655746459961,21.610984802246094,2.901263475418091,12.035785675048828,18.062572479248047,8.219147682189941,7.281647205352783,12.050296783447266,9.499439239501953,3.9626739025115967,4.69015645980835,24.574321746826172,24.874568939208984,9.791949272155762,-4.867168426513672,19.439014434814453,0.7849865555763245,21.745723724365234,12.035578727722168,22.607263565063477,11.642753601074219,8.718899726867676,0.17771148681640625,19.466081619262695,9.467968940734863,0.8336058855056763,4.400899887084961,18.038402557373047,8.414560317993164,24.621484756469727,3.1670804023742676,5.422317028045654,2.6296353340148926,5.485397815704346,3.169950485229492,-14.118916511535645,9.461615562438965,3.0646798610687256,7.628985404968262,5.310871124267578,22.609079360961914,0.018428634852170944,23.752540588378906,8.58115005493164,23.08904266357422,7.172311305999756,18.08698081970215,11.686966896057129,9.695788383483887,23.510766983032227,9.74177360534668,0.7874069809913635,-6.4956254959106445,23.924156188964844,23.489696502685547,11.675606727600098,21.74617576599121,12.038250923156738,2.0862154960632324,10.847869873046875,12.11626148223877,5.757687091827393,38.72057342529297,4.293111324310303,9.700812339782715,9.704570770263672,2.2183992862701416,4.884899139404297,2.5005264282226562,2.770094633102417,23.725797653198242,19.43531036376953,4.206752300262451,3.0961825847625732,2.7960243225097656,14.862836837768555,3.8835926055908203,4.6202850341796875,11.155978202819824,10.186559677124023,21.254562377929688,23.96512794494629,23.756629943847656,12.788389205932617,23.41107940673828,5.25652599334 ...

# %%
print(svd_model.explained_variance_ratio_)
# Out:
# [0.10683409 0.03681909 0.03628827 0.02902549 0.02681229 0.02488121
#  0.02031895 0.01869439 0.01757428 0.01713488 0.01524389 0.01473215
#  0.01470781 0.01455871 0.01382487 0.0132256  0.01221768 0.01207748
#  0.011155   0.00940412 0.00905084 0.00859345 0.00825216 0.00814738
#  0.00796898 0.00780381 0.00751939 0.00727723 0.00685554 0.00664217
#  0.00649512 0.0062659  0.0061346  0.00598767 0.0057754  0.00568255
#  0.00565843 0.00555319 0.00547862 0.00549845 0.00533743 0.00532395
#  0.00512139 0.00506321 0.00500917 0.00487922 0.00473922 0.00455787
#  0.00444749 0.00440525 0.0042735  0.00424993 0.00421682 0.00412552
#  0.00408025 0.00396641 0.00391604 0.00383022 0.00380583 0.00374549
#  0.00366816 0.00357325 0.00350366 0.00350549 0.00347406 0.00338995
#  0.00337525 0.00328815 0.00326105 0.00317488 0.00309581 0.00305715
#  0.00301199 0.00296829 0.0029368  0.00284594 0.00282532 0.00280029
#  0.00274722 0.00265983 0.00261671 0.00258984 0.00254736 0.00250024
#  0.00249515 0.0024062  0.00240905 0.00238574 0.00234149 0.0023151
#  0.00227057 0.00226967 0.00222512 0.00217685 0.00212909 0.0021054
#  0.00208378 0.00204007 0.0020182  0.00198596]
